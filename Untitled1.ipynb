# %%
import pandas as pd

# %%
df = pd.read_csv('./work/データ分析/data/Batting.csv')

# %%
pwd
# Out:
# 'C:\\Users\\s_sag'

# %%
df
# Out:
#         player_id  year  stint team_id league_id    g     ab     r     h  \
# 0       abercda01  1871      1     TRO       NaN    1    4.0   0.0   0.0
# 1        addybo01  1871      1     RC1       NaN   25  118.0  30.0  32.0
# 2       allisar01  1871      1     CL1       NaN   29  137.0  28.0  40.0
# 3       allisdo01  1871      1     WS3       NaN   27  133.0  28.0  44.0
# 4       ansonca01  1871      1     RC1       NaN   25  120.0  29.0  39.0
# ...           ...   ...    ...     ...       ...  ...    ...   ...   ...
# 101327   zitoba01  2015      1     OAK        AL    3    0.0   0.0   0.0
# 101328  zobribe01  2015      1     OAK        AL   67  235.0  39.0  63.0
# 101329  zobribe01  2015      2     KCA        AL   59  232.0  37.0  66.0
# 101330  zuninmi01  2015      1     SEA        AL  112  350.0  28.0  61.0
# 101331   zychto01  2015      1     SEA        AL   13    0.0   0.0   0.0
#
#         double  ...   rbi   sb   cs    bb     so  ibb  hbp   sh   sf  g_idp
# ...

# %%
df['BA'] = df['H'] / df['AB']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\jupyterbook\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'H'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-b1778fc27af6> in <module>
# ...

# %%
df.to_excel('mlb_batting_stats.xlsx')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-12-b949501642ee> in <module>
# ----> 1 df.to_excel('mlb_batting_stats.xlsx')
#
# ~\anaconda3\envs\jupyterbook\lib\site-packages\pandas\core\generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2186             inf_rep=inf_rep,
#    2187         )
# -> 2188         formatter.write(
#    2189             excel_writer,
#    2190             sheet_name=sheet_name,
#
# ~\anaconda3\envs\jupyterbook\lib\site-packages\pandas\io\formats\excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options)
#     813             # abstract class 'ExcelWriter' with abstract attributes 'engine',
# ...

# %%
df.to_excel('mlb_batting_stats.xlsx')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b949501642ee> in <module>
# ----> 1 df.to_excel('mlb_batting_stats.xlsx')
#
# NameError: name 'df' is not defined

# %%
df
# Out:
#         player_id  year  stint team_id league_id    g     ab     r     h  \
# 0       abercda01  1871      1     TRO       NaN    1    4.0   0.0   0.0
# 1        addybo01  1871      1     RC1       NaN   25  118.0  30.0  32.0
# 2       allisar01  1871      1     CL1       NaN   29  137.0  28.0  40.0
# 3       allisdo01  1871      1     WS3       NaN   27  133.0  28.0  44.0
# 4       ansonca01  1871      1     RC1       NaN   25  120.0  29.0  39.0
# ...           ...   ...    ...     ...       ...  ...    ...   ...   ...
# 101327   zitoba01  2015      1     OAK        AL    3    0.0   0.0   0.0
# 101328  zobribe01  2015      1     OAK        AL   67  235.0  39.0  63.0
# 101329  zobribe01  2015      2     KCA        AL   59  232.0  37.0  66.0
# 101330  zuninmi01  2015      1     SEA        AL  112  350.0  28.0  61.0
# 101331   zychto01  2015      1     SEA        AL   13    0.0   0.0   0.0
#
#         double  ...   rbi   sb   cs    bb     so  ibb  hbp   sh   sf  g_idp
# ...

# %%
df.to_excel('./work/データ分析/data/mlb_batting_stats.xlsx')

# %%
df['BA'] = df['h'] / df['ab']

# %%
df
# Out:
#         player_id  year  stint team_id league_id    g     ab     r     h  \
# 0       abercda01  1871      1     TRO       NaN    1    4.0   0.0   0.0
# 1        addybo01  1871      1     RC1       NaN   25  118.0  30.0  32.0
# 2       allisar01  1871      1     CL1       NaN   29  137.0  28.0  40.0
# 3       allisdo01  1871      1     WS3       NaN   27  133.0  28.0  44.0
# 4       ansonca01  1871      1     RC1       NaN   25  120.0  29.0  39.0
# ...           ...   ...    ...     ...       ...  ...    ...   ...   ...
# 101327   zitoba01  2015      1     OAK        AL    3    0.0   0.0   0.0
# 101328  zobribe01  2015      1     OAK        AL   67  235.0  39.0  63.0
# 101329  zobribe01  2015      2     KCA        AL   59  232.0  37.0  66.0
# 101330  zuninmi01  2015      1     SEA        AL  112  350.0  28.0  61.0
# 101331   zychto01  2015      1     SEA        AL   13    0.0   0.0   0.0
#
#         double  ...   sb   cs    bb     so  ibb  hbp   sh   sf  g_idp  \
# ...

# %%
from urllib. parse import urljoin
base_url = (
    "https://raw.githubusercontent.com/practical-jupyter/sample-data/master/anime/"
) 
anime_csv = urljoin( base_url, "anime.csv") 
print(anime_csv)
# Out:
# https://raw.githubusercontent.com/practical-jupyter/sample-data/master/anime/anime.csv

# %%
import pandas as pd
n225_csv = urljoin(base_url, "n225.csv")
pd.read_csv(n225_csv)
# Out:
#            Date      Open      High       Low     Close
# 0    2016-01-04  18818.58  18951.12  18394.43  18450.98
# 1    2016-01-05  18398.76  18547.38  18327.52  18374.00
# 2    2016-01-06  18410.57  18469.38  18064.30  18191.32
# 3    2016-01-07  18139.77  18172.04  17767.34  17767.34
# 4    2016-01-08  17562.23  17975.31  17509.64  17697.96
# ..          ...       ...       ...       ...       ...
# 240  2016-12-26  19394.41  19432.48  19385.94  19396.64
# 241  2016-12-27  19353.43  19478.58  19352.06  19403.06
# 242  2016-12-28  19392.11  19442.13  19364.73  19401.72
# 243  2016-12-29  19301.04  19301.04  19092.22  19145.14
# 244  2016-12-30  18997.68  19176.81  18991.59  19114.37
#
# [245 rows x 5 columns]
